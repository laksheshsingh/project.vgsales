# %%
                                    ''' DATASET NAME - video game sales 


  this data set tells us about how games industry have been in progress since time. and we will be doing it with 
  some logical questions and by analysing our data set using CSV file / data provided.
  
   Why this data and how its helpfull?  
    
  Since from the beginning of era of computers , parallel to that video game entertainment started and along with that thousands 
  of games started to be created by different publishing industries and created a crazy environment among the people. 
  not only new video games were created but some more innovative, entertaining , luxury ,featured video games platform came into   an existence for example -PLAYStations by SONY , XBOX by microsoft , virtual gaming #googlevisualgames by googles. since these 
  are some of the million/billion dollar worth companies. there are game publishing industries such as EASPORTS, MINICLIP,ESPN 
  and so many others.
  This data here is going to tell
  data is helpful as far as we refer for game developing industries they analyse data like which country has most no. of sales 
  in a particular genre of the game?. what is the total of global sales of the game ? 
  Questions like this help them in featuring games and selling to the profitable customers. '''
# Out:
# ' DATASET NAME - video game sales \n\n\n  this data set tells us about how games industry have been in progress since time. and we will be doing it with \n  some logical questions and by analysing our data set using CSV file / data provided.\n  \n   Why this data and how its helpfull?  \n    \n  Since from the beginning of era of computers , parallel to that video game entertainment started and along with that thousands \n  of games started to be created by different publishing industries and created a crazy environment among the people. \n  not only new video games were created but some more innovative, entertaining , luxury ,featured video games platform came into   an existence for example -PLAYStations by SONY , XBOX by microsoft , virtual gaming #googlevisualgames by googles. since these \n  are some of the million/billion dollar worth companies. there are game publishing industries such as EASPORTS, MINICLIP,ESPN \n  and so many others.\n  This data here is going to tell\n  dat
# ...

# %%
                                     
#import the needed libraries for project as pandas used for manipulating data and numpy for numerical operations.
import pandas as pd     
import numpy as np 
'''now i am importing data set in a variable name called 'game' using pandas and i have imported pandas as pd for fast and easy 
use . and after importing data into variable name 'game' we just have to refer that data using 'game' variable.

below is the syntax to do so 
'''
game=pd.read_csv(r"C:\Users\lakshesh singh sisod\Downloads\vgsales.csv (1)\vgsales.csv")
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.info()       # this particular syntax gives us the value count and data type of each column as how many non null 
                     #values are there and whats there data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
game.shape    # this syntax here gives us total no. of rows and column in format (no.of rows,no. of columns)
# Out:
# (16598, 11)

# %%
game.head()    # this gives us the first 5 rows of the data set .
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# LETS UNDERSTAND  ABOUT OUR DATASET-----
# column first :'rank' is just a S.no./serial no.
#
# column second :'name' is official name of the game.
#
# colimn third :'platform' is the name of featured device for which the game has been launches like is it an mobile game , pc ,
# playstation,xbox etc.
#
# column fourth :'year' is a year of releasing of game
#
# column fifth: 'genre' is a underlying theme of game like is it a sports game,adventure game ,combat game etc.
#
# column sixth : 'publisher' is the name of game developing company which has organised and developed a particular game
#
# column seven :'NA_Sales' is the sale of that game in North America
#
# column eight:'EU_Sales'is sales in europe
#
# column nine: 'JP_Sales' is sales in japan
#
# column ten: 'Other_Sales' is sales in some other countries
#
# column eleven :'Global_Sales' is sales of game around the globe
#
#
#
#
#
#
#
#
#
# game.tail()     # this gives us the last 5 rows of data set .

# %%
game.isnull()     ##tells us the values which are null.
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False  False  False      False     False     False
# 16594  False  False     False  False  False      False     False     False
# 16595  False  False     False  False  False      False     False     False
# 16596  False  False     False  False  False      False     False     False
# 16597  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
# False tells us about not having any null value

# %%
game.isnull().sum()   #this syntax tells about no. of null values in each column
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Fill missing cells with column median
game["Year"].fillna((game["Year"].median()), inplace=True)

# %%
import seaborn as sns  #importing seaborn library for further analysis
import matplotlib    #to analyse using plot 
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("darkgrid")

# %%
game.describe().transpose()   # here we have done stastical analysis to see count , mean standard deviation , 25 percentile 
                             # (also known as quantile) q1 , 50 and 75 percentile and max .
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16598.0  2006.416134     5.781686  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.scatterplot(data=game,
                x="Year",
                y="Global_Sales")

plt.show()
#Exploring the relationship between Year and Global Sales

# %%
'''conclusion-From the following scatterplot, we can see that most game titles made global sales of below roughly $15 million mark,
with some exceptionally good ones going beyond that. We even notice some outliers, 
with one game in particular released in 2006 making a breakthrough.'''
# Out:
# 'conclusion-From the following scatterplot, we can see that most game titles made global sales of below roughly $15 million mark,\nwith some exceptionally good ones going beyond that. We even notice some outliers, \nwith one game in particular released in 2006 making a breakthrough.'

# %%
#Total Count of Games for each Platform

#PlayStation 2 and Nintendo DS have the most game titles in their platform. 
#In fact, they are almost equal in count, which makes it all the more interesting to see.

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.countplot(data=game,
              x="Platform",
              order = game["Platform"].value_counts().index,
              palette="Dark2")
plt.xticks(rotation=90)
plt.show()

# %%
#Total Count of Games for each Genre

#Action seems to be the genre where most game title can be found,
#with Sports, Misc and Role-Playing following not too far behind.
#Puzzle appears to be the least popular among game developers.

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.countplot(data=game,
              x="Genre",
              order = game["Genre"].value_counts().index,
              palette="Dark2")
plt.xticks(rotation=90)
plt.show()

# %%
#Explore correlation between features

#It is expected that all the sales columns are correlated to one another based on the heatmap below.
#There seems to be no significant correlation between the other columns.

# %%
from sklearn.preprocessing import LabelEncoder

# Encode selected categorical columns to prepare for heatmap plotting
encoded_df = game.copy()
categ = ["Platform", "Genre", "Publisher"]
encoder = LabelEncoder()
encoded_df[categ] = encoded_df[categ].apply(encoder.fit_transform)

# Create correlation heatmap
plt.figure(figsize=(6,6), dpi=120)
sns.heatmap(encoded_df.corr(), 
            cmap="flare",
            annot=True)

plt.show()

# %%
#Q1: What are the top 10 games making the most sales globally?

# %%
# Using the `.nlargest()` method, we can easily extract the top n values of a dataframe
game.nlargest(10, "Global_Sales")
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
#Q2: What are the top 5 gaming Genres that are making high sales?

# %%
# We will use the `.groupby()`method to consolidate the indivisual genre, and the `.agg()` method to perform the sum function
sales_genre = game.groupby("Genre").agg({"Global_Sales": pd.Series.sum})
sales_genre.nlargest(5, "Global_Sales")
# Out:
#               Global_Sales
# Genre
# Action             1751.18
# Sports             1330.93
# Shooter            1037.37
# Role-Playing        927.37
# Platform            831.37

# %%
#Q3: - Which game made the most sales per region and globally?

# %%
print(f"NA: {game.nlargest(1, 'NA_Sales').values[0,1]}")
print(f"EU: {game.nlargest(1, 'EU_Sales').values[0,1]}")
print(f"JP: {game.nlargest(1, 'JP_Sales').values[0,1]}")
print(f"Other: {game.nlargest(1, 'Other_Sales').values[0,1]}")
print(f"Global: {game.nlargest(1, 'Global_Sales').values[0,1]}")
# Out:
# NA: Wii Sports
# EU: Wii Sports
# JP: Pokemon Red/Pokemon Blue
# Other: Grand Theft Auto: San Andreas
# Global: Wii Sports

# %%
#Q4:- Which Publishers made the most sales?

# %%
sales_publisher = game.groupby("Publisher").agg({"Global_Sales": pd.Series.sum})
sales_publisher.nlargest(5, "Global_Sales")
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1786.56
# Electronic Arts                   1110.32
# Activision                         727.46
# Sony Computer Entertainment        607.50
# Ubisoft                            474.72

# %%
#Q5: What PC-FX games were sold?

# %%
game.query("Platform == 'PCFX'")
# Out:
#         Rank                                Name Platform    Year  \
# 14556  14559  Blue Breaker: Ken Yorimo Hohoemi o     PCFX  1996.0
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 14556  Role-Playing       NEC       0.0       0.0      0.03          0.0
#
#        Global_Sales
# 14556          0.03

# %%
#Q6: Are there any games that made lesser sales than this one game on PC-FX? If yes, how many are there?

# %%
# The `.len()` method will return the count of rows
len(game.query("Global_Sales < 0.03"))
# Out:
# 1689

# %%
#Inferences
#Based on our analysis, we can draw the following inferences:

#Wii Sports, published in 2006, made the most sales worldwide. This is echoed by both NA and EU regions. 
#However, it is a different story in other regions, with Pokemon Red/Pokemon Blue dominating in Japan and Grand Theft Auto:
#San Andreas everywhere else 

#50% of top 10 games utilized the Wii Platform, making it one of the most successful consoles. 
#This could be because of the fact the the Wii system was one of the most innovative consoles in its time out there 
#by taking advantage of motion controls

#Action, Sports and Shooter are the most popular genres with high game titles as well as high global sales made

#Nintendo snatch the spot for the Publisher that made the most global sales. Unsurprising is the fact that the top 10
#games are all published by Nintendo!

#The PC-FX console had only one game title in its arsenal, 
#which was published only in Japan. Interestingly enough, it is not the game that made the least amount of sales.'''
